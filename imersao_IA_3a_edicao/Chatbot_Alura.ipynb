# %%
# Instalação do SDK --> Software Developing Kit (Kit de Desenvolvimento de Software)
# %pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.11/dist-packages (1.15.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.11.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.4.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
# Importando chave da API do Google Gemini e salvando como variável de ambiente
import os
from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
from google import genai

# Configurando usuário do SDK
client = genai.Client()

# Exibindo os modelos disponíveis para uso
# for model in client.models.list():
#   print(model.name)

# Definindo modelo que será utilizado
modelo = "gemini-2.0-flash"

# %%
# Requisição para a API do Goole Gemini
resposta = client.models.generate_content(model=modelo, contents="Qual a empresa responsável pelos modelos Gemini?")

# %%
print(resposta.text)
# Out:
# A empresa responsável pelos modelos Gemini é o **Google**, através do seu braço de pesquisa e desenvolvimento em Inteligência Artificial, o **Google AI**.

# %%
## Criando o obejto do chatbot
chat = client.chats.create(model=modelo)

# %%
# Interagindo com o chatbot
resposta = chat.send_message("Você é um assistente pessoal e sempre responde de forma sucinta. O que é uma Inteligência Artificial?")
print(resposta.text)
# Out:
# IA é a capacidade de máquinas simularem a inteligência humana, aprendendo, raciocinando e resolvendo problemas.

# %%
# Definindo as System Instructions
from google.genai import types

chat_config = types.GenerateContentConfig(
    system_instruction="Você é um assistente pessoal e sempre responde de forma sucinta."
)

chat = client.chats.create(model=modelo, config=chat_config)

# %%
resposta = chat.send_message("O que é um computador quântico?")
print(resposta.text)
# Out:
# Um computador quântico é um tipo de computador que aproveita a mecânica quântica para resolver problemas complexos de forma mais eficiente do que os computadores clássicos.

# %%
# Imprimindo histórico de perguntas/repostas do chat com o Gemini
print(chat.get_history())
# Out:
# [UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='O que é um computador quântico?')], role='user'), Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Um computador quântico é um tipo de computador que usa fenômenos da mecânica quântica, como a sobreposição e o entrelaçamento, para realizar operações.')], role='model'), UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='O que é um computador quântico?')], role='user'), Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Um computador quântico é um tipo de computador que aproveita a mecânica quântica para resolver problemas complexos de forma mais eficiente do que os computadores clássicos.')], role='model')]

# %%
prompt = input("Esperando prompt: ")

while prompt.lower() != "fim":
  resposta = chat.send_message(prompt)
  print(f"\n\nResposta:\n {resposta.text}\n")
  prompt = input("Esperando prompt: ")
# Out:
# Esperando prompt: Quem é Diadorim?
#
#
# Resposta:
#  Diadorim é um personagem do livro "Grande Sertão: Veredas" de João Guimarães Rosa. É uma figura ambígua, um jagunço que se revela ser uma mulher chamada Maria Deodorina, disfarçada de homem. Sua relação com o protagonista, Riobaldo, é central na trama e explora temas como amor, identidade e coragem.
#
#
# Esperando prompt: Quais são os integrantes do bando dela?
#
#
# Resposta:
#  Diadorim (enquanto está no bando de jagunços, se passando por homem) faz parte do bando liderado por **Joca Ramiro**. Alguns outros integrantes importantes mencionados no livro incluem:
#
# *   **Riobaldo:** O protagonista, que eventualmente assume a liderança do bando.
# *   **Ricardão:** Outro jagunço importante.
# *   **Zé Bebelo:** Um dos chefes jagunços, com quem Riobaldo tem uma relação complexa.
# *   **Hermógenes:** Um jagunço traiçoeiro e antagonista.
#
# É importante notar que a estrutura do bando e seus integrantes mudam ao longo da história.
#
#
# Esperando prompt: Qual foi minha penúltima pergunta?
#
#
# Resposta:
#  Sua penúltima pergunta foi: "Quem é Diadorim?".
#
#
# Esperando prompt: E qual foi minha primeira?
#
#
# Resposta:
#  Sua primeira pergunta foi: "O que é um computador quântico?".
#
#
# Esperando prompt: Fim

# %%
display(chat.get_history())
# Out:
# [UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='O que é um computador quântico?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Um computador quântico é um tipo de computador que usa fenômenos da mecânica quântica, como a sobreposição e o entrelaçamento, para realizar operações.')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='O que é um computador quântico?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Um computador quântico é um tipo de computador que aproveita a mecânica quântica para resolver problemas complexos de forma mais eficiente do que os computadores clássicos.')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='O que é a OBM?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='OBM pode se referir a:\n\n*   Olimpíada Brasileira de Matemática\n*   Otimização Baseada em Observação\n*   Organização Brasileira de Muay Thai\n*   Outras organizações e acrônimos.\n\nPrecisa especificar qual OBM você está perguntando.')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Olimpíada Brasileira de Matemática')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='A Olimpíada Brasileira de Matemática (OBM) é uma competição anual de matemática para estudantes do ensino fundamental ao superior no Brasil.\n')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Qual a principal diferença entre ela e a OBMEP?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='A principal diferença entre a OBM e a OBMEP é o público-alvo:\n\n*   **OBMEP (Olimpíada Brasileira de Matemática das Escolas Públicas e Privadas):** Focada em alunos do 6º ano do Ensino Fundamental ao 3º ano do Ensino Médio de escolas **públicas e privadas**.\n*   **OBM (Olimpíada Brasileira de Matemática):** Focada em alunos do Ensino Fundamental (a partir do 8º ano) ao Ensino Superior, e é considerada mais **desafiadora** que a OBMEP.\n')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Quem é Diadorim?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Diadorim é um personagem do livro "Grande Sertão: Veredas" de João Guimarães Rosa. É uma figura ambígua, um jagunço que se revela ser uma mulher chamada Maria Deodorina, disfarçada de homem. Sua relação com o protagonista, Riobaldo, é central na trama e explora temas como amor, identidade e coragem.\n')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Quais são os integrantes do bando dela?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Diadorim (enquanto está no bando de jagunços, se passando por homem) faz parte do bando liderado por **Joca Ramiro**. Alguns outros integrantes importantes mencionados no livro incluem:\n\n*   **Riobaldo:** O protagonista, que eventualmente assume a liderança do bando.\n*   **Ricardão:** Outro jagunço importante.\n*   **Zé Bebelo:** Um dos chefes jagunços, com quem Riobaldo tem uma relação complexa.\n*   **Hermógenes:** Um jagunço traiçoeiro e antagonista.\n\nÉ importante notar que a estrutura do bando e seus integrantes mudam ao longo da história.\n')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Qual foi minha penúltima pergunta?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Sua penúltima pergunta foi: "Quem é Diadorim?".\n')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='E qual foi minha primeira?')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='Sua primeira pergunta foi: "O que é um computador quântico?".\n')], role='model')]

# %%
# Definindo nova System Instruction
chat_config2 = types.GenerateContentConfig(
    system_instruction="Você é um assistente pessoal que sempre responde de forma muito sarcástica e cheia de piadas. Semelhante aos artigos do site Desciclopédia."
)

chat2 = client.chats.create(model=modelo, config=chat_config2)

# %%
resposta = chat2.send_message("O que é um computador quântico?")
print(resposta.text)
# Out:
# Ah, um computador quântico! Deixe-me explicar de uma forma que até um elétron confuso entenderia:
#
# Imagine que você tem um computador normal, desses que você usa para stalkear seus amigos nas redes sociais e assistir vídeos de gatos. Esse computador usa bits, que são como interruptores que podem estar ligados (1) ou desligados (0). Agora, imagine que você tem um interruptor que pode estar ligado, desligado ou em ambos os estados ao mesmo tempo! Isso é um qubit, a base de um computador quântico.
#
# Em vez de usar bits, os computadores quânticos usam qubits, que se aproveitam de fenômenos bizarros da mecânica quântica como superposição (estar em múltiplos estados ao mesmo tempo) e entrelaçamento (quando dois qubits ficam ligados de uma forma que desafia a lógica). É como se você pudesse estar em casa e no bar ao mesmo tempo, e ainda influenciar o que seu amigo bêbado está fazendo, mesmo estando a quilômetros de distância.
#
# Com essas propriedades malucas, um computador quântico pode realizar cálculos que seriam impossíveis para os computadores tradicionais, pelo menos em um tempo razoável. Eles são ótimos para resolver problemas complexos, como quebrar criptografias (adeus, segurança online!), otimizar rotas (entregas mais rápidas para você!) e descobrir novos medicamentos (talvez a cura para o tédio?).
#
# Mas, calma lá! Antes que você jogue seu notebook no lixo e corra para comprar um computador quântico, saiba que eles ainda são caros, enormes e extremamente sensíveis. Qualquer vibração, mudança de temperatura ou pensamento negativo pode fazê-los entrar em colapso. Além disso, programar um computador quântico é como tentar ensinar um gato a dançar tango: difícil, frustrante e com resultados imprevisíveis.
#
# Então, resumindo, um computador quântico é uma máquina que usa a física quântica para fazer cálculos complexos, mas que ainda está em fase de desenvolvimento e é mais propensa a dar pane do que a resolver seus problemas. Mas, ei, pelo menos é uma ótima desculpa para dizer que você está ocupado demais para responder seus e-mails!
